# %% [markdown]
# # Parse methylpy

# %%
from ALLCools.mcds import RegionDS
from ALLCools.dmr.parse_methylpy import methylpy_to_region_ds

# %%
methylpy_prefix = '/home/hanliu/cemba3c/projects/ALLCools/HIPBulk/DMR/snmC_CT'
methylpy_dms = f'{methylpy_prefix}_rms_results.tsv.gz'
methylpy_dmr = f'{methylpy_prefix}_rms_results_collapsed.tsv'

# %%
methylpy_to_region_ds(dmr_path=methylpy_dmr, output_dir='HIP_methylpy')
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 48 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
RegionDS.open('HIP_methylpy')
# Out:
# INFO:root:Using dmr as region_dim
# <xarray.RegionDS>
# Dimensions:      (dmr: 2337497, sample: 10)
# Coordinates:
#   * dmr          (dmr) <U15 'snmC_CT-0' 'snmC_CT-1' ... 'snmC_CT-2337496'
#     dmr_chrom    (dmr) <U5 dask.array<chunksize=(36524,), meta=np.ndarray>
#     dmr_end      (dmr) int64 dask.array<chunksize=(73047,), meta=np.ndarray>
#     dmr_ndms     (dmr) int64 dask.array<chunksize=(73047,), meta=np.ndarray>
#     dmr_start    (dmr) int64 dask.array<chunksize=(73047,), meta=np.ndarray>
#   * sample       (sample) <U17 'snmC_ASC' 'snmC_CA1' ... 'snmC_ODC' 'snmC_OPC'
# Data variables:
#     dmr_da_frac  (sample, dmr) float64 dask.array<chunksize=(1, 146094), meta=np.ndarray>
#     dmr_state    (sample, dmr) int16 dask.array<chunksize=(2, 292188), meta=np.ndarray>
# Attributes:
#     region_dim:          dmr
#     region_ds_location:  /home/hanliu/project/allcools_doc/cluster_level/Regi...
